# %% [markdown]
# For my part of the project I chose to analyse the arrest data in each neighborhood. The data table that I found is very easy to understand and has a lot of information, however we are only really looking at the number of arrests in each neighborhood. Naturally, the neighborhood that has the least amount of arrests is the "best" neighborhood in Pittsburgh by my standards.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Here I imported everything necessary to analyse the arrest data file. And below I will import and print out the data table.

# %%
data = pd.read_csv("Arrest-Data/ArrestData.csv", parse_dates=True)
data
# Out:
#          _id       PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0          1  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1          2  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2          3  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3          4  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4          5  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# ...      ...      ...       ...   ...    ...  ...                  ...
# 65159  86420  2062508  23142445  17.0      M    B  2023-09-19T15:00:00
# 65160  86421  2062509  23142476  47.0      M    W  2023-09-08T02:49:00
# 65161  86422  2062510  23142478  37.0      M    B  2023-09-16T02:26:00
# 65162  86423  2062511  23175388  35.0      F    B  2023-11-05T01:15:00
# 65163  86424  2062512  23142575  45.0      M    B  2023-09-08T08:05:00
#
#                                          ARRESTLOCATION  \
# 0             4700 Block Centre AV Pittsburgh, PA 15213
# 1      4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2            900 Block Freeport RD Fox Chapel, PA 15238
# 3           Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4             900 Block Woodlow ST Pittsburgh, PA 15205
# ...                                                 ...
# 65159       3100 Block Brighton RD Pittsburgh, PA 15212
# 65160           1500 Block Obey ST Pittsburgh, PA 15205
# 65161             600 Block 1st AV Pittsburgh, PA 15219
# 65162         300 Block E North AV Pittsburgh, PA 15212
# 65163           2100 Block Reed ST Pittsburgh, PA 15219
#
#                                                 OFFENSES  \
# 0                                     3929 Retail Theft.
# 1           13(a)(16) Possession of Controlled Substance
# 2                                     3929 Retail Theft.
# 3      5503 Disorderly Conduct. / 5505 Public Drunken...
# 4      2702 Aggravated Assault. / 2705 Recklessy Enda...
# ...                                                  ...
# 65159  907 Possessing Instruments of Crime. / 2701 Si...
# 65160                          2706 Terroristic Threats.
# 65161  4910 Tampering with or Fabricating Physical Ev...
# 65162  2501 Criminal Homicide. / 2706 Terroristic Thr...
# 65163  2701(a)(1) Simple Assault - Intent., Know., Re...
#
#                                         INCIDENTLOCATION  \
# 0              4700 Block Centre AV Pittsburgh, PA 15213
# 1       4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2             900 Block Freeport RD Fox Chapel, PA 15238
# 3            Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4              900 Block Woodlow ST Pittsburgh, PA 15205
# ...                                                  ...
# 65159       3200 Block Rothpletz ST Pittsburgh, PA 15212
# 65160            1500 Block Obey ST Pittsburgh, PA 15205
# 65161  Strawberry WY & Smithfield ST Pittsburgh, PA 1...
# 65162       2100 Block Park Hill DR Pittsburgh, PA 15221
# 65163            2100 Block Reed ST Pittsburgh, PA 15219
#
#             INCIDENTNEIGHBORHOOD INCIDENTZONE  INCIDENTTRACT  \
# 0                     Bloomfield            5          804.0
# 1                   Outside City          OSC         5599.0
# 2                       Westwood            5         2811.0
# 3                 East Allegheny            1         2304.0
# 4                Crafton Heights            5         2814.0
# ...                          ...          ...            ...
# 65159         Marshall-Shadeland            1         2715.0
# 65160            Crafton Heights            6         2815.0
# 65161  Central Business District            2          201.0
# 65162                 East Hills            5         1306.0
# 65163           Crawford-Roberts            2          305.0
#
#        COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION          X          Y
# 0                   8.0                    2.0 -79.949277  40.452551
# 1                   NaN                    NaN -80.088018  40.440136
# 2                   9.0                    2.0 -79.891803  40.486625
# 3                   1.0                    1.0 -80.001939  40.454080
# 4                   2.0                    5.0 -80.052204  40.445900
# ...                 ...                    ...        ...        ...
# 65159               1.0                    1.0 -80.026817  40.475814
# 65160               NaN                    NaN        NaN        NaN
# 65161               6.0                    6.0 -79.997289  40.442151
# 65162               9.0                    2.0 -79.874068  40.453204
# 65163               NaN                    NaN        NaN        NaN
#
# [65164 rows x 17 columns]

# %% [markdown]
# This data table shows all the information about arrest data in Pittsburgh and includes the neighborhood for each arrest.
# There is a lot of information we dont need, only really the neighborhood. Now I will use .groupby and .count to sort by the neighborhoods.

# %%
data.groupby("INCIDENTNEIGHBORHOOD").count()
# Out:
#                        _id    PK   CCR   AGE  GENDER  RACE  ARRESTTIME  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center      1229  1229  1229  1223    1229  1229        1229
# Allegheny West         127   127   127   126     127   127         127
# Allentown              933   933   933   926     933   933         933
# Arlington              302   302   302   301     302   302         302
# Arlington Heights      153   153   153   153     153   153         153
# ...                    ...   ...   ...   ...     ...   ...         ...
# Upper Lawrenceville    187   187   187   186     187   187         187
# West End               281   281   281   281     281   281         281
# West Oakland           313   313   313   312     313   313         313
# Westwood               222   222   222   220     222   222         222
# Windgap                123   123   123   123     123   123         123
#
#                       ARRESTLOCATION  OFFENSES  INCIDENTLOCATION  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center                1229      1229              1229
# Allegheny West                   127       127               127
# Allentown                        933       933               933
# Arlington                        302       302               302
# Arlington Heights                153       153               153
# ...                              ...       ...               ...
# Upper Lawrenceville              187       187               187
# West End                         281       281               281
# West Oakland                     313       313               313
# Westwood                         222       222               222
# Windgap                          123       123               123
#
#                       INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center              1229           1229               890
# Allegheny West                 127            127               109
# Allentown                      933            933               868
# Arlington                      302            302               282
# Arlington Heights              153            153               129
# ...                            ...            ...               ...
# Upper Lawrenceville            187            187               158
# West End                       281            281               221
# West Oakland                   313            313               262
# Westwood                       222            222               169
# Windgap                        123            123               104
#
#                       PUBLIC_WORKS_DIVISION    X    Y
# INCIDENTNEIGHBORHOOD
# Allegheny Center                        890  916  916
# Allegheny West                          109  109  109
# Allentown                               868  879  879
# Arlington                               282  287  287
# Arlington Heights                       129  129  129
# ...                                     ...  ...  ...
# Upper Lawrenceville                     158  158  158
# West End                                221  222  222
# West Oakland                            262  264  264
# Westwood                                169  176  176
# Windgap                                 104  109  109
#
# [98 rows x 16 columns]

# %% [markdown]
# Now I will get rid of all the unnessecary data that is in this data table.

# %%
chart = data["INCIDENTNEIGHBORHOOD"].value_counts().sort_values(ascending=False)
chart
# Out:
# Central Business District    4278
# South Side Flats             3398
# Carrick                      2311
# East Allegheny               2161
# Homewood South               2057
#                              ...
# Regent Square                  36
# Central Northside              23
# Mt. Oliver Boro                18
# Troy Hill-Herrs Island          6
# Mt. Oliver Neighborhood         2
# Name: INCIDENTNEIGHBORHOOD, Length: 98, dtype: int64

# %% [markdown]
# This gives us the neighborhoods with the most arrests to  the neighborhoods with the least arrests. This allows us to find our "best" neighborhood, or the neighborhood with the least amounts of arrests, Mt. Oliver Neighborhood.
# Now I will show several charts and graphs to display this data.

# %%
chart.plot.bar(rot = 0)

# %%
detailed = chart.tail(20)
detailed.plot.bar(rot = 0)

# %%
detailed = chart.tail(10)
detailed.plot.bar(rot = 0)

# %%
detailed = chart.tail(5)
detailed.plot.bar(rot = 0)
